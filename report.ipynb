# %%
import pandas as pd
import numpy as np
import os

# %%
from logic import *
import logic

# %%
Person = 4

# %%
logic.Get_text(logic.Search('OD_mean',Person), OD)
# Out:
# 'Уровень организационного развития вашей НКО выше и составляет 3.85'

# %%
Text1 = 'Уровень организационного развития НКО отражает состояние опрошенных организаций по основным параметрам деятельности и свидетельствует об их организационной устойчивости.'
Text1 += os.linesep
Text1 += 'Общий уровень организационного развития НКО {OD_mean} из 5'.format(OD_mean=Table.loc[:,'OD_mean'].mean().round(2))
Text1 += os.linesep
Text1 += 'Это свидетельствует о том, что устойчивость организаций находится на среднем уровне и по многим параметрам деятельность НКО могут стать более эффективными и устойчивыми.'
Text1 += os.linesep
Text1 += logic.Get_text(logic.Search('OD_mean',Person),OD)
Text1 += os.linesep
Text1 += 'Из 12 показателей, характеризующих уровень организационного развития НКО, наивысшее значение у Организационной культуры ({value}). Это объясняется тем, что коллектив большинства опрошенных организаций разделяет общие ценности и в организациях выстроена понятная система внутренней коммуникации.'.format(value=Table_main.loc['Организационная культура'].mean().round(2))
Text1 += os.linesep
Text1 += 'Показатель Проекты и мероприятия также превышает значение 4 из 5 и достигает {value}. Опрошенные НКО реализуют взаимосвязанные между собой проекты и мероприятия, направленные на достижение основной миссии организации, по ним имеется календарный план и четкий набор измеримых целей, НКО ведут управленческий учет (учет поступлений и расходов по целевому назначению, по проектам/мероприятиям).'.format(value=Table_main.loc['Проекты и мероприятия'].mean().round(2))
Text1 += os.linesep
Text1 += 'Опрошенные организации также обладают достаточно высоким уровнем Открытости изменениям {value}. В НКО поддерживаются новые идеи и предложения, а их сотрудники стремятся постоянно развивать свои знания и навыки).'.format(value=Table_main.loc['Открытость изменениям'].mean().round(2))
Text1 += os.linesep
Text1 += 'Наименьшее значение наблюдается у показателя Адвокация {value}, характеризующего субъективную степень оценки возможности НКО оказать влияние на происходящее на муниципальном, региональном и федеральных уровнях. Такая деятельность выходит за рамки привычного «проектного подхода» и требует специфических навыков со стороны НКО. Результаты исследования показывают, что опрошенные организации являются более сервисно-ориентированными и в меньшей мере способны (по субъективным самооценкам) оказывать влияние на более широкие институциональные процессы.'.format(value=Table_main.loc['Адвокация'].mean().round(2))
Text1 += os.linesep
Text1 += 'Второй наиболее низкий показатель – Финансовая устойчивость {value}. Несмотря на то, что многие НКО обладают необходимой материально технической базой (есть помещение для работы, техника, ПО), в редких случаях у организаций имеется детальный фандрайзинговый план, расходы на фандрайзинг включены в годовой бюджет организации и имеющихся финансовых ресурсов хватает для текущей работы.'.format(value=Table_main.loc['Финансовая устойчивость'].mean().round(2))
Text1 += os.linesep
Text1 += 'Также низким уровнем обладает Работа с рисками ({value}). Отсутствие необходимого финансирования и низкий уровень диверсификации бюджета, нехватка сотрудников и их эмоциональное и профессиональное выгорание – ключевые составляющие высокого уровня рисков организационной устойчивости опрошенных НКО.'.format(value=Table_main.loc['Работа с рисками'].mean().round(2))
print(Text1)
# Out:
# Уровень организационного развития НКО отражает состояние опрошенных организаций по основным параметрам деятельности и свидетельствует об их организационной устойчивости.
# Общий уровень организационного развития НКО 3.56 из 5
# Это свидетельствует о том, что устойчивость организаций находится на среднем уровне и по многим параметрам деятельность НКО могут стать более эффективными и устойчивыми.
# Уровень организационного развития вашей НКО выше и составляет 3.85
# Из 12 показателей, характеризующих уровень организационного развития НКО, наивысшее значение у Организационной культуры (4.16). Это объясняется тем, что коллектив большинства опрошенных организаций разделяет общие ценности и в организациях выстроена понятная система внутренней коммуникации.
# ...

# %%
# Для того, чтобы вывести сильные/слабые стороны
Weakness1 = []
Strength1 = []
for groups in TableGroups:
    match Search(TableGroups.loc[0,groups],Person,multiple=True).return_comparison():
        case 'more':
            Strength1.append(groups)
        case 'less':
            Weakness1.append(groups)
Weakness1, Strength1
# Out:
# (['Организационная культура',
#   'Проекты и мероприятия',
#   'Волонтеры',
#   'Финансовая устойчивость',
#   'Оценка и мониторинг'],
#  ['Стратегия и планирование',
#   'Управление организацией',
#   'Внешние коммуникации',
#   'Адвокация',
#   'Работа с рисками'])

# %%
Text2 = 'Показатель Стратегия и планирование характеризует степень опоры организации на ее миссию и ценности, принятие решений, основанных на данных, и умение учитывать риски.'
Text2 += os.linesep
Text2 += 'Значение показателя Стратегия и планирование по всем опрошенным НКО – {value} из 5'.format(value=Table_main.loc['Стратегия и планирование'].mean().round(2))
Text2 += os.linesep
Text2 += logic.Get_text(logic.Search(['Q03_r1','Q03_r2','Q03_r3','Q03_r4','Q03_r5','Q03_r6'],Person,multiple=True),logic.Strategy1)
Text2 += os.linesep
Text2 += 'Наиболее сильные стороны в Стратегии и планировании среди всех опрошенных НКО – это наличие миссии организации, которая отражает ее цели и ценности, и учет рисков в работе организации. Более слабой стороной является то, что в своей работе НКО в меньшей ориентируются на стратегию развития организации.'
Text2 += os.linesep
print(Text2)
# Out:
# Показатель Стратегия и планирование характеризует степень опоры организации на ее миссию и ценности, принятие решений, основанных на данных, и умение учитывать риски.
# Значение показателя Стратегия и планирование по всем опрошенным НКО – 3.96 из 5
# Этот показатель выше у вашей организации и составляет 4.5.
# Наиболее сильные стороны в Стратегии и планировании среди всех опрошенных НКО – это наличие миссии организации, которая отражает ее цели и ценности, и учет рисков в работе организации. Более слабой стороной является то, что в своей работе НКО в меньшей ориентируются на стратегию развития организации.

# %%
'''TempTable = TableGroups.loc[0,'Стратегия и планирование']
Strength_strategy = []
for question in TempTable:
    match Search(question,Person).return_comparison():
        case 'more':
            Strength_strategy.append(question)
            Strength_strategy.append(os.linesep)
Strength_strategy
'''
# Out:
# "TempTable = TableGroups.loc[0,'Стратегия и планирование']\nStrength_strategy = []\nfor question in TempTable:\n    match Search(question,Person).return_comparison():\n        case 'more':\n            Strength_strategy.append(question)\n            Strength_strategy.append(os.linesep)\nStrength_strategy\n"

# %%
Text2_1 = ''
TempTable = TableGroups.loc[0,'Стратегия и планирование']
if Check_search(TempTable,Person,state='more') == True:
    Text2_1 = 'К числу достижений вашей организации по показателю Стратегия и планирование, где значения вашей организации выше средних значений, относится:'
    Text2_1 += os.linesep
    if Search('Q03_r1',Person).return_comparison() == 'more':
        Text2_1 += 'Ориентация на миссию в работе организации'
        Text2_1 += os.linesep
    if Search('Q03_r2',Person).return_comparison() == 'more':
        Text2_1 += 'Наличие рабочей версии стратегии развития организации '
        Text2_1 += os.linesep
    if Search('Q03_r3',Person).return_comparison() == 'more':
        Text2_1 += 'Учет задач стратегии развития в повседневной деятельности сотрудников '
        Text2_1 += os.linesep
    if Search('Q03_r4',Person).return_comparison() == 'more':
        Text2_1 += 'Наличие конкретного и реалистичного плана работы на ближайший год'
        Text2_1 += os.linesep
    if Search('Q03_r5',Person).return_comparison() == 'more':
        Text2_1 += 'Принятие решений, основанных на данных и аналитике'
        Text2_1 += os.linesep
    if Search('Q03_r6',Person).return_comparison() == 'more':
        Text2_1 += 'Учет и минимизация внутренних и внешних рисков в работе'
        Text2_1 += os.linesep
print(Text2_1)
# Out:
# К числу достижений вашей организации по показателю Стратегия и планирование, где значения вашей организации выше средних значений, относится:
# Ориентация на миссию в работе организации
# Наличие рабочей версии стратегии развития организации
# Учет задач стратегии развития в повседневной деятельности сотрудников
# Наличие конкретного и реалистичного плана работы на ближайший год
# Учет и минимизация внутренних и внешних рисков в работе

# %%
Text2_2 = ''
TempTable = TableGroups.loc[0,'Стратегия и планирование']
if Check_search(TempTable,Person,state='more',is_upper=True):
    Text2_2 = 'Ваши сильные стороны в Стратегии и планировании наравне с НКО в целом:'
    Text2_2 += os.linesep
    if Search('Q03_r1',Person).is_upper() == True:
        Text2_2 += 'Ориентация на миссию в работе организации'
        Text2_2 += os.linesep
    if Search('Q03_r2',Person).is_upper() == True:
        Text2_2 += 'Наличие рабочей версии стратегии развития организации '
        Text2_2 += os.linesep
    if Search('Q03_r3',Person).is_upper() == True:
        Text2_2 += 'Учет задач стратегии развития в повседневной деятельности сотрудников '
        Text2_2 += os.linesep
    if Search('Q03_r4',Person).is_upper() == True:
        Text2_2 += 'Наличие конкретного и реалистичного плана работы на ближайший год'
        Text2_2 += os.linesep
    if Search('Q03_r5',Person).is_upper() == True:
        Text2_2 += 'Принятие решений, основанных на данных и аналитике'
        Text2_2 += os.linesep
    if Search('Q03_r6',Person).is_upper() == True:
        Text2_2 += 'Учет и минимизация внутренних и внешних рисков в работе'
        Text2_2 += os.linesep
print(Text2_2)
# Out:
# Ваши сильные стороны в Стратегии и планировании наравне с НКО в целом:
# Ориентация на миссию в работе организации
# Наличие рабочей версии стратегии развития организации
# Наличие конкретного и реалистичного плана работы на ближайший год
# Учет и минимизация внутренних и внешних рисков в работе

# %%
Search('Q03_r3',Person).is_upper(), Search('Q03_r3',Person).return_comparison(), Search('Q03_r3',Person).return_value(), Search('Q03_r3',Person).mean
# Out:
# (False, 'more', 4.0, 3.41)

# %%
Text2_3 = ''
TempTable = TableGroups.loc[0,'Стратегия и планирование']
if Check_search(TempTable,Person,state='less') == True:
    Text2_3 = 'Ваши слабые стороны в Стратегии и планировании, требующие внимания в первую очередь:'
    Text2_3 += os.linesep
    if Search('Q03_r1',Person).return_comparison() == 'less':
        Text2_3 += 'Низкая ориентация на миссию в работе организации'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Если вы сможете обсудить свою миссию с коллегами и отразить ее в каком-либо из внутренних документов организации, это поможет вам получить более четкое понимание целей деятельности организации и вести осознанное стратегическое планирование в будущем.'
        Text2_3 += os.linesep
    if Search('Q03_r2',Person).return_comparison() == 'less':
        Text2_3 += 'Отсутствие рабочей версии стратегии развития организации'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Разработка стратегии развития организации с фиксацией целей, показателей, сроков и мероприятий, и прочего позволит более эффективно и управляемо достигать миссии организации. План должен отражать интересы и цели всех направлений деятельности вашей организации, быть реалистичным и учитывать текущую ресурсную обеспеченность. Пригласите коллег к совместной разработке стратегии развития организации.'
        Text2_3 += os.linesep
    if Search('Q03_r3',Person).return_comparison() == 'less':
        Text2_3 += 'Стратегия развития не учитывается в повседневной деятельности сотрудников'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Стратегия развития организации должна быть рабочим документом, на который ориентируются сотрудники в своей повседневной работе. Стратегия развития должна давать всем сотрудникам общее представление о том, куда стремится организация и как этого можно достичь. Стратегический план может быть пересмотрен при изменении внешних условий, вашей ресурсной обеспеченности или при возникновении иных влияющих факторов.'
        Text2_3 += os.linesep
    if Search('Q03_r4',Person).return_comparison() == 'less':
        Text2_3 += 'Отсутствие конкретного и реалистичного плана работы на ближайший год'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Вместе с коллегами вы сможете обсудить и подготовить план работы на год. Учитывайте в нем сезонность и график приема заявок на грантовые конкурсы. Отразите в плане желаемые измеряемые показатели по итогам года, основные шаги для их достижения, сроки этапов и ответственных за их выполнение.'
        Text2_3 += os.linesep
    if Search('Q03_r5',Person).return_comparison() == 'less':
        Text2_3 += 'Низкий уровень использования данных и аналитики при принятии управленческих решений'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Использование данных внутренней аналитики или внешних исследований существенно повышает обоснованность принимаемых управленческих решений. Вы можете (1) определить перечень показателей внутренней работы НКО, данные по которым важны для управления организацией и конкретных направлений, (2) определить источники получения таких данных, (3) разрабатывать и корректировать управленческие решения с учетом получаемых данных. Для данных внешних исследований или данных статистики – аналогичная последовательность.'
        Text2_3 += os.linesep
    if Search('Q03_r6',Person).return_comparison() == 'less':
        Text2_3 += 'Недостаточный учёт рисков в работе организации'
        Text2_3 += os.linesep
        Text2_3 += 'Рекомендация: Систематический учет внешних и внутренних рисков в работе организации позволят, в случае их возникновения, более эффективно минимизировать последствия наступления. В таком случае ваша организация будет готова к разрешению различных ситуаций и с большей вероятностью сохранит свою устойчивость.'
        Text2_3 += os.linesep
print(Text2_3)
# Out:
# Ваши слабые стороны в Стратегии и планировании, требующие внимания в первую очередь:
# Низкий уровень использования данных и аналитики при принятии управленческих решений
# Рекомендация: Использование данных внутренней аналитики или внешних исследований существенно повышает обоснованность принимаемых управленческих решений. Вы можете (1) определить перечень показателей внутренней работы НКО, данные по которым важны для управления организацией и конкретных направлений, (2) определить источники получения таких данных, (3) разрабатывать и корректировать управленческие решения с учетом получаемых данных. Для данных внешних исследований или данных статистики – аналогичная последовательность.

# %%
Text2_4 = ''
TempTable = TableGroups.loc[0,'Стратегия и планирование']
if Check_search(TempTable,Person,state='less',is_upper=False) == True:
    Text2_4 = 'Так же, как и по НКО в целом, к числу ваших слабых сторон в Стратегии и планировании относится:'
    Text2_4 += os.linesep
    if Search('Q03_r1',Person).is_lower() == True:
        Text2_4 += 'Низкая ориентация на миссию в работе организации'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Если вы сможете обсудить свою миссию с коллегами и отразить ее в каком-либо из внутренних документов организации, это поможет вам получить более четкое понимание целей деятельности организации и вести осознанное стратегическое планирование в будущем.'
        Text2_4 += os.linesep
    if Search('Q03_r2',Person).is_lower() == True:
        Text2_4 += 'Отсутствие рабочей версии стратегии развития организации'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Разработка стратегии развития организации с фиксацией целей, показателей, сроков и мероприятий, и прочего позволит более эффективно и управляемо достигать миссии организации. План должен отражать интересы и цели всех направлений деятельности вашей организации, быть реалистичным и учитывать текущую ресурсную обеспеченность. Пригласите коллег к совместной разработке стратегии развития организации.'
        Text2_4 += os.linesep
    if Search('Q03_r3',Person).is_lower() == True:
        Text2_4 += 'Стратегия развития не учитывается в повседневной деятельности сотрудников'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Стратегия развития организации должна быть рабочим документом, на который ориентируются сотрудники в своей повседневной работе. Стратегия развития должна давать всем сотрудникам общее представление о том, куда стремится организация и как этого можно достичь. Стратегический план может быть пересмотрен при изменении внешних условий, вашей ресурсной обеспеченности или при возникновении иных влияющих факторов.'
        Text2_4 += os.linesep
    if Search('Q03_r4',Person).is_lower() == True:
        Text2_4 += 'Отсутствие конкретного и реалистичного плана работы на ближайший год'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Вместе с коллегами вы сможете обсудить и подготовить план работы на год. Учитывайте в нем сезонность и график приема заявок на грантовые конкурсы. Отразите в плане желаемые измеряемые показатели по итогам года, основные шаги для их достижения, сроки этапов и ответственных за их выполнение.'
        Text2_4 += os.linesep
    if Search('Q03_r5',Person).is_lower() == True:
        Text2_4 += 'Низкий уровень использования данных и аналитики при принятии управленческих решений'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Использование данных внутренней аналитики или внешних исследований существенно повышает обоснованность принимаемых управленческих решений. Вы можете (1) определить перечень показателей внутренней работы НКО, данные по которым важны для управления организацией и конкретных направлений, (2) определить источники получения таких данных, (3) разрабатывать и корректировать управленческие решения с учетом получаемых данных. Для данных внешних исследований или данных статистики – аналогичная последовательность.'
        Text2_4 += os.linesep
    if Search('Q03_r6',Person).is_lower() == True:
        Text2_4 += 'Недостаточный учёт рисков в работе организации'
        Text2_4 += os.linesep
        Text2_4 += 'Рекомендация: Систематический учет внешних и внутренних рисков в работе организации позволят, в случае их возникновения, более эффективно минимизировать последствия наступления. В таком случае ваша организация будет готова к разрешению различных ситуаций и с большей вероятностью сохранит свою устойчивость.'
        Text2_4 += os.linesep
print(Text2_4)

# %%
Text2 += Text2_1
Text2 += Text2_2
Text2 += Text2_3
Text2 += Text2_4
print(Text2)
# Out:
# Показатель Стратегия и планирование характеризует степень опоры организации на ее миссию и ценности, принятие решений, основанных на данных, и умение учитывать риски.
# Значение показателя Стратегия и планирование по всем опрошенным НКО – 3.96 из 5
# Этот показатель выше у вашей организации и составляет 4.5.
# Наиболее сильные стороны в Стратегии и планировании среди всех опрошенных НКО – это наличие миссии организации, которая отражает ее цели и ценности, и учет рисков в работе организации. Более слабой стороной является то, что в своей работе НКО в меньшей ориентируются на стратегию развития организации.
# К числу достижений вашей организации по показателю Стратегия и планирование, где значения вашей организации выше средних значений, относится:
# Ориентация на миссию в работе организации
# Наличие рабочей версии стратегии развития организации
# Учет задач стратегии развития в повседневной деятельности сотрудников
# Наличие конкретного и реалистичного плана работы на ближайший год
# ...
